# %%
n=int(input("enter a number"))
list=[]
for i in range(n):
  num=int(input("enter a number"))
  list.append(num)
print(sum(list))
# Out:
# enter a number4
# enter a number55
# enter a number43
# enter a number4345
# enter a number4555
# 8998
